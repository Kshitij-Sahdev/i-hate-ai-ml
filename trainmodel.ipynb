# %%
# !git clone https://github.com/kumarvivek9088/aslsigndataset.git
# Out:
# fatal: destination path 'aslsigndataset' already exists and is not an empty directory.

# %%
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard
import os

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

val_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 128

train_generator = train_datagen.flow_from_directory(
    '/content/aslsigndataset/splitdataset48x48/train',
    target_size=(48, 48),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
)

validation_generator = val_datagen.flow_from_directory(
    '/content/aslsigndataset/splitdataset48x48/val',
    target_size=(48, 48),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
)
# Out:
# Found 1473 images belonging to 6 classes.
# Found 372 images belonging to 6 classes.

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)
# Out:
# ['A', 'M', 'N', 'S', 'T', 'blank']

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(6, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'] )

# %%
# !rm -rf Logs
logdir = os.path.join("Logs")
tensorboard_callback = TensorBoard(log_dir=logdir)

# %%
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[tensorboard_callback]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.1660 - loss: 1.7955 - val_accuracy: 0.1875 - val_loss: 1.7861
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1719 - loss: 1.7926 - val_accuracy: 0.1953 - val_loss: 1.7880
# Epoch 3/100
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.1769 - loss: 1.7866 - val_accuracy: 0.1875 - val_loss: 1.7821
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1953 - loss: 1.7794 - val_accuracy: 0.1719 - val_loss: 1.7886
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.1904 - loss: 1.7828 - val_accuracy: 0.2031 - val_loss: 1.7635
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2109 - loss: 1.7700 - val_accuracy: 0.1758 - val_loss: 1.7713
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.1793 - loss: 1.7659 - val_accuracy: 0.1953 - val_loss: 1.7109
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2031 - loss: 1.7001 - val_accuracy: 0.1797 - val_loss: 1.7235
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.2022 - loss: 1.7340 - val_accuracy: 0.1836 - val_loss: 1.7013
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.2188 - loss: 1.6687 - val_accuracy: 0.1836 - val_loss: 1.6966
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.1773 - loss: 1.6918 - val_accuracy: 0.2422 - val_loss: 1.6184
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2422 - loss: 1.6467 - val_accuracy: 0.2422 - val_loss: 1.6110
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.2639 - loss: 1.6280 - val_accuracy: 0.3047 - val_loss: 1.5962
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3516 - loss: 1.5981 - val_accuracy: 0.2812 - val_loss: 1.5871
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.2727 - loss: 1.5805 - val_accuracy: 0.3281 - val_loss: 1.5319
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3672 - loss: 1.4950 - val_accuracy: 0.2617 - val_loss: 1.5312
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.2983 - loss: 1.5345 - val_accuracy: 0.3242 - val_loss: 1.4895
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2812 - loss: 1.4803 - val_accuracy: 0.3594 - val_loss: 1.5169
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.3159 - loss: 1.4774 - val_accuracy: 0.3086 - val_loss: 1.4323
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3984 - loss: 1.4398 - val_accuracy: 0.3555 - val_loss: 1.3833
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.3835 - loss: 1.4322 - val_accuracy: 0.4336 - val_loss: 1.3220
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4062 - loss: 1.3524 - val_accuracy: 0.4570 - val_loss: 1.3292
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4525 - loss: 1.3436 - val_accuracy: 0.4922 - val_loss: 1.2877
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4531 - loss: 1.2731 - val_accuracy: 0.5000 - val_loss: 1.2710
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4772 - loss: 1.2810 - val_accuracy: 0.4414 - val_loss: 1.1876
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4609 - loss: 1.1949 - val_accuracy: 0.4648 - val_loss: 1.1532
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4812 - loss: 1.1373 - val_accuracy: 0.5273 - val_loss: 0.9687
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5391 - loss: 1.0231 - val_accuracy: 0.5469 - val_loss: 0.9476
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.4600 - loss: 1.0690 - val_accuracy: 0.5039 - val_loss: 1.1494
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5156 - loss: 1.0537 - val_accuracy: 0.5352 - val_loss: 0.9422
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5398 - loss: 0.9559 - val_accuracy: 0.5547 - val_loss: 0.9203
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6172 - loss: 0.8623 - val_accuracy: 0.5273 - val_loss: 0.9102
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.5594 - loss: 0.9029 - val_accuracy: 0.6406 - val_loss: 0.8126
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5469 - loss: 1.0267 - val_accuracy: 0.5781 - val_loss: 0.8924
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.5879 - loss: 0.8955 - val_accuracy: 0.6445 - val_loss: 0.7685
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5859 - loss: 0.8743 - val_accuracy: 0.6797 - val_loss: 0.7281
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.6678 - loss: 0.7560 - val_accuracy: 0.6641 - val_loss: 0.7794
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6484 - loss: 0.7839 - val_accuracy: 0.7383 - val_loss: 0.6209
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6820 - loss: 0.7014 - val_accuracy: 0.7344 - val_loss: 0.5783
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7344 - loss: 0.5687 - val_accuracy: 0.7656 - val_loss: 0.5329
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7325 - loss: 0.5702 - val_accuracy: 0.7461 - val_loss: 0.5221
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7422 - loss: 0.4727 - val_accuracy: 0.7539 - val_loss: 0.5714
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7270 - loss: 0.5861 - val_accuracy: 0.8008 - val_loss: 0.4477
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7734 - loss: 0.4899 - val_accuracy: 0.7773 - val_loss: 0.5313
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7816 - loss: 0.5054 - val_accuracy: 0.7930 - val_loss: 0.4600
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7422 - loss: 0.4967 - val_accuracy: 0.7656 - val_loss: 0.4755
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7979 - loss: 0.4439 - val_accuracy: 0.7812 - val_loss: 0.4263
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8438 - loss: 0.3196 - val_accuracy: 0.8008 - val_loss: 0.3388
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7821 - loss: 0.4251 - val_accuracy: 0.8203 - val_loss: 0.4223
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8125 - loss: 0.3843 - val_accuracy: 0.8398 - val_loss: 0.3762
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8006 - loss: 0.3968 - val_accuracy: 0.7852 - val_loss: 0.4191
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8308 - loss: 0.3717 - val_accuracy: 0.7969 - val_loss: 0.3860
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.8311 - loss: 0.3820 - val_accuracy: 0.8594 - val_loss: 0.3356
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9077 - loss: 0.3035 - val_accuracy: 0.9102 - val_loss: 0.2989
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8359 - loss: 0.3568 - val_accuracy: 0.8672 - val_loss: 0.2574
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8906 - loss: 0.2482 - val_accuracy: 0.8320 - val_loss: 0.3278
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8526 - loss: 0.3314 - val_accuracy: 0.8789 - val_loss: 0.3316
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9141 - loss: 0.2267 - val_accuracy: 0.8828 - val_loss: 0.3221
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8755 - loss: 0.2871 - val_accuracy: 0.8984 - val_loss: 0.2845
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8438 - loss: 0.2951 - val_accuracy: 0.9062 - val_loss: 0.2719
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8980 - loss: 0.2571 - val_accuracy: 0.8789 - val_loss: 0.2887
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9141 - loss: 0.2585 - val_accuracy: 0.9141 - val_loss: 0.1923
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.9100 - loss: 0.2378 - val_accuracy: 0.9219 - val_loss: 0.2435
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9062 - loss: 0.2030 - val_accuracy: 0.8984 - val_loss: 0.2804
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9213 - loss: 0.2189 - val_accuracy: 0.9023 - val_loss: 0.2454
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9219 - loss: 0.2440 - val_accuracy: 0.9336 - val_loss: 0.1804
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9342 - loss: 0.1879 - val_accuracy: 0.9219 - val_loss: 0.2291
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9453 - loss: 0.2421 - val_accuracy: 0.9375 - val_loss: 0.1863
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9225 - loss: 0.2187 - val_accuracy: 0.9492 - val_loss: 0.1162
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9077 - loss: 0.2339 - val_accuracy: 0.9414 - val_loss: 0.1249
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9517 - loss: 0.1459 - val_accuracy: 0.9297 - val_loss: 0.1631
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8984 - loss: 0.2352 - val_accuracy: 0.9180 - val_loss: 0.1797
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9341 - loss: 0.2248 - val_accuracy: 0.9492 - val_loss: 0.2148
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9141 - loss: 0.2174 - val_accuracy: 0.9531 - val_loss: 0.1725
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9515 - loss: 0.1322 - val_accuracy: 0.9023 - val_loss: 0.2131
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9062 - loss: 0.2055 - val_accuracy: 0.9180 - val_loss: 0.3582
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9239 - loss: 0.2782 - val_accuracy: 0.9609 - val_loss: 0.1193
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9297 - loss: 0.2147 - val_accuracy: 0.9492 - val_loss: 0.1480
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9504 - loss: 0.1719 - val_accuracy: 0.9336 - val_loss: 0.1666
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9231 - loss: 0.1294 - val_accuracy: 0.9609 - val_loss: 0.0998
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9619 - loss: 0.1231 - val_accuracy: 0.9336 - val_loss: 0.1503
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9844 - loss: 0.0882 - val_accuracy: 0.9453 - val_loss: 0.1225
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9565 - loss: 0.1441 - val_accuracy: 0.9570 - val_loss: 0.0813
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9766 - loss: 0.0965 - val_accuracy: 0.9609 - val_loss: 0.1062
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9673 - loss: 0.1018 - val_accuracy: 0.9414 - val_loss: 0.1227
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9844 - loss: 0.0547 - val_accuracy: 0.9531 - val_loss: 0.1042
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9673 - loss: 0.0860 - val_accuracy: 0.9609 - val_loss: 0.0950
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9609 - loss: 0.0594 - val_accuracy: 0.9570 - val_loss: 0.0937
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9891 - loss: 0.0501 - val_accuracy: 0.9609 - val_loss: 0.1074
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9688 - loss: 0.0725 - val_accuracy: 0.9766 - val_loss: 0.0538
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.9735 - loss: 0.0733 - val_accuracy: 0.9688 - val_loss: 0.0701
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9846 - loss: 0.0632 - val_accuracy: 0.9883 - val_loss: 0.0537
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9677 - loss: 0.1000 - val_accuracy: 0.9727 - val_loss: 0.1234
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9531 - loss: 0.1604 - val_accuracy: 0.9648 - val_loss: 0.1007
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9632 - loss: 0.1549 - val_accuracy: 0.9570 - val_loss: 0.1287
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9688 - loss: 0.1490 - val_accuracy: 0.9297 - val_loss: 0.1864
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.9516 - loss: 0.1280 - val_accuracy: 0.9570 - val_loss: 0.1017
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9766 - loss: 0.0911 - val_accuracy: 0.9531 - val_loss: 0.1250
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9793 - loss: 0.0842 - val_accuracy: 0.9492 - val_loss: 0.1090
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9766 - loss: 0.0535 - val_accuracy: 0.9648 - val_loss: 0.0697

# %%
model_json = model.to_json()
with open("/signlanguagedetectionmodel48x48.json",'w') as json_file:
    json_file.write(model_json)
model.save("/signlanguagedetectionmodel48x48.keras")
